# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
datatset = pd.read_csv('Position_Salaries.csv')
X = datatset.iloc[:, 1:-1].values
y = datatset.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X,y, color = 'red')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results(degree = 2)

# %%
plt.scatter(X,y, color = 'red')
X_poly = poly_reg.fit_transform(X)
plt.plot(X, lin_reg_2.predict(X_poly), color = 'blue')
plt.title('Degree = 2')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (degree = 4)

# %%
plt.scatter(X,y, color = 'red')
X_poly = poly_reg.fit_transform(X)
plt.plot(X, lin_reg_2.predict(X_poly), color = 'blue')
plt.title('Degree = 4')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X,y, color = 'red')
X_poly = poly_reg.fit_transform(X)
plt.plot(X, lin_reg_2.predict(X_poly), color = 'blue')
plt.title('Degree = 4')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()
# Out:
# /tmp/ipython-input-3654294450.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
Alex = [[6.5]]
lin_reg.predict(Alex)
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
Alex = poly_reg.fit_transform([[6.5]])
lin_reg_2.predict(Alex)
# Out:
# array([158862.45265155])
